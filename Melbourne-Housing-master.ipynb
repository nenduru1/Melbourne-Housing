# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pylab as plt

# %%
data=pd.read_csv('Melbourne_housing_extra_data.csv')
# data=pd.read_csv('Melbourne_housing_extra_data.csv',dayfirst=True,parse_dates=True,index_col='Date')
data.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St    2.0    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St    2.0    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St    3.0    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St    3.0    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode Bedroom2 Bathroom Car Landsize BuildingArea  \
# 0  3/09/2016       2.5    3067.0        2        1   1      126          NaN
# 1  3/12/2016       2.5    3067.0        2        1   1      202          NaN
# 2  4/02/2016       2.5    3067.0        2        1   0      156           79
# 3  4/02/2016       2.5    3067.0        3        2   1        0          NaN
# 4  4/03/2017       2.5    3067.0        3        2   0      134          150
#
#   YearBuilt CouncilArea Lattitude Longtitude
# ...

# %%
def val_counts(var):
    print(data[var].value_counts())
    print(data[var].nunique())

# %%
val_counts('Suburb')
val_counts('Rooms')
val_counts('Type')
val_counts('Method') #can ignore
val_counts('SellerG')#can ignore
# val_counts('year')
# val_counts('month') # month 3-8 more sales
val_counts('Postcode')
# Out:
# Reservoir             444
# Bentleigh East        314
# Richmond              301
# Glen Iris             266
# Preston               263
# Kew                   251
# Brighton              248
# South Yarra           242
# St Kilda              235
# Brunswick             228
# Coburg                226
# Camberwell            226
# Brighton East         226
# Balwyn North          224
# Essendon              222
# Hawthorn              216
# Glenroy               213
# Malvern East          212
# Northcote             210
# Port Melbourne        204
# Pascoe Vale           193
# Prahran               187
# Balwyn                180
# Yarraville            175
# Bentleigh             170
# Thornbury             164
# Toorak                164
# Carnegie              161
# Hawthorn East         161
# Hampton               157
#                      ...
# Albion                 33
# Spotswood              31
# Essendon West          30
# South Kingsville       29
# ...

# %%
data.groupby('Postcode')['Price'].mean().round().astype(int)
# Out:
# Postcode
# 3000.0     701237
# 3002.0    1390227
# 3003.0     958640
# 3006.0     634458
# 3008.0     875000
# 3011.0     773547
# 3012.0     739548
# 3013.0     945365
# 3015.0     979722
# 3016.0    1194479
# 3018.0     855139
# 3019.0     645379
# 3020.0     625838
# 3021.0     563024
# 3025.0     755567
# 3031.0     797362
# 3032.0     916211
# 3033.0     777125
# 3034.0     832062
# 3039.0    1116106
# 3040.0    1058348
# 3041.0    1067759
# 3042.0     782726
# 3043.0     660180
# 3044.0     744087
# 3046.0     660247
# 3047.0     485114
# 3051.0     846656
# 3052.0    1364958
# 3053.0    1049613
#            ...
# 3126.0    2351400
# 3127.0    1476780
# 3128.0    1195681
# 3141.0    1026034
# 3142.0    1699373
# 3143.0    1451671
# 3144.0    1874346
# 3145.0    1386849
# 3146.0    1587807
# 3147.0    1377830
# 3148.0    1003033
# 3161.0    1009167
# 3162.0    1084348
# 3163.0     909937
# 3165.0    1056442
# 3166.0    1052433
# 3167.0     960679
# 3181.0    1011799
# ...

# %%
data.groupby('Postcode')['Price'].apply(lambda x:x.count())
# Out:
# Postcode
# 3000.0     93
# 3002.0     22
# 3003.0     25
# 3006.0     36
# 3008.0      5
# 3011.0    171
# 3012.0    213
# 3013.0    139
# 3015.0    177
# 3016.0    117
# 3018.0     66
# 3019.0     48
# 3020.0    309
# 3021.0     21
# 3025.0     82
# 3031.0    166
# 3032.0    233
# 3033.0    110
# 3034.0     80
# 3039.0    129
# 3040.0    246
# 3041.0    106
# 3042.0    168
# 3043.0     25
# 3044.0    160
# 3046.0    301
# 3047.0     22
# 3051.0     59
# 3052.0     33
# 3053.0     43
#          ...
# 3126.0     45
# 3127.0    148
# 3128.0     52
# 3141.0    187
# 3142.0    108
# 3143.0     82
# 3144.0     68
# 3145.0    138
# 3146.0    167
# 3147.0    122
# 3148.0     45
# 3161.0     36
# 3162.0     56
# 3163.0    244
# 3165.0    274
# 3166.0     82
# 3167.0     64
# 3181.0    158
# 3182.0    192
# 3183.0     21
# 3184.0    109
# 3185.0     70
# 3186.0    177
# 3187.0    152
# 3188.0    166
# 3189.0     63
# 3204.0    223
# 3205.0     73
# 3206.0     81
# 3207.0    144
# ...

# %%
data.groupby('Postcode')['Price'].apply(lambda x:x.isnull().sum())
# data.groupby('Postcode')['Price'].isnull().sum()
# Out:
# Postcode
# 3000.0     34
# 3002.0      7
# 3003.0     11
# 3006.0     11
# 3008.0      5
# 3011.0     33
# 3012.0     48
# 3013.0     36
# 3015.0     32
# 3016.0     23
# 3018.0      4
# 3019.0      7
# 3020.0     31
# 3021.0      4
# 3025.0     12
# 3031.0     18
# 3032.0     38
# 3033.0     13
# 3034.0      8
# 3039.0     23
# 3040.0     48
# 3041.0     17
# 3042.0      7
# 3043.0      2
# 3044.0     33
# 3046.0     53
# 3047.0      2
# 3051.0     17
# 3052.0      4
# 3053.0      6
#          ...
# 3126.0     28
# 3127.0     66
# 3128.0     19
# 3141.0     55
# 3142.0     56
# 3143.0     57
# 3144.0     75
# 3145.0     86
# 3146.0     99
# 3147.0     50
# 3148.0     19
# 3161.0      8
# 3162.0     22
# 3163.0     41
# 3165.0     40
# 3166.0     23
# 3167.0     10
# 3181.0    105
# 3182.0     43
# 3183.0      5
# 3184.0     47
# 3185.0     26
# 3186.0     71
# 3187.0     74
# 3188.0     51
# 3189.0      8
# 3204.0     34
# 3205.0     19
# 3206.0     34
# 3207.0     60
# ...

# %%
data['Price']=data['Price'].groupby(data['Postcode']).apply(lambda x :x.fillna(round(x.mean())))

# %%
data
# Out:
#                Suburb                 Address  Rooms Type      Price Method  \
# 0          Abbotsford           68 Studley St    2.0    h  1027385.0     SS
# 1          Abbotsford            85 Turner St    2.0    h  1480000.0      S
# 2          Abbotsford         25 Bloomburg St    2.0    h  1035000.0      S
# 3          Abbotsford      18/659 Victoria St    3.0    u  1027385.0     VB
# 4          Abbotsford            5 Charles St    3.0    h  1465000.0     SP
# 5          Abbotsford        40 Federation La    3.0    h   850000.0     PI
# 6          Abbotsford             55a Park St    4.0    h  1600000.0     VB
# 7          Abbotsford            16 Maugie St    4.0    h  1027385.0     SN
# 8          Abbotsford            53 Turner St    2.0    h  1027385.0      S
# 9          Abbotsford            99 Turner St    2.0    h  1027385.0      S
# 10         Abbotsford          129 Charles St    2.0    h   941000.0      S
# ...
